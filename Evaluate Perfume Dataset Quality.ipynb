# %%
from pymongo import MongoClient
from pymongo import errors
from pprint import pprint
import numpy as np
import re

# %%
def connect_database():
    client = MongoClient('localhost', 27017)
    return client

# %%
client = connect_database()

# %%
perfume_database = client.Perfume_Database

# %%
pprint(perfume_database.list_collection_names())
# Out:
# ['Cleared_Crawled_Perfumes',
#  'Fragrances_Backup_02/22/2024',
#  'Scraped_Perfumes',
#  'Extra01',
#  'Fragrances_Backup_02/24/2024',
#  'Fragrances_Backup_02/16/2024',
#  'Extra03',
#  'Metadata',
#  'Perfumes',
#  'Extra02',
#  'Fragrances',
#  'Fragrances_Quality',
#  'Crawled_Perfumes']

# %%
fragrances_quality_collection = perfume_database.Fragrances_Quality
fragrances_collection = perfume_database.Fragrances

# %% [markdown]
# load the first analysis before any quality improvement

# %%
quality_analysis = fragrances_quality_collection.find_one(sort=[("Date", -1)])

# %%
pprint(quality_analysis)
# Out:
# {'Date': datetime.datetime(2024, 2, 16, 23, 5, 48, 74000),
#  '_id': ObjectId('65cfea4c1d1d2de3ce3f6a5c'),
#  'count': 1000,
#  'fields': [{'count': 1000,
#              'hasDuplicates': False,
#              'name': '_id',
#              'path': ['_id'],
#              'probability': 1,
#              'type': 'ObjectId',
#              'types': [{'bsonType': 'ObjectId',
#                         'count': 1000,
#                         'hasDuplicates': False,
#                         'name': 'ObjectId',
#                         'path': ['_id'],
#                         'probability': 1,
#                         'unique': 1000,
#                         'values': ['65c3d3942be6a0a6d64f654e',
#                                    '65c3d3942be6a0a6d64f5fac',
#                                    '65c3d3942be6a0a6d64f64e7',
#                                    '65c3ecc62be6a0a6d64f676e',
#                                    '65a6abcabcd0c58b31680cc5',
#                                    '65a5afe6bacca2969b0ed42c',
#                                    '65c3d3942be6a0a6d64f6255',
#                                    '65a7cb9e96d56388983d1440',
#                                    '65a7ae1696d56388983d0c81',
#                                    '65a92a5449fb27db67a4f2d0',
#                                    '65c3d3942be6a0a6d64f629c',
#                                    '65a7773996d56388983d0a02',
#                                    '65c3d3942be6a0a6d64f60e2',
#                                    '65a6c1456ce432599ea774dc',
#                                    '65a7bfd696d56388983d0dbe',
#                                    '65c3d3942be6a0a6d64f6007',
#                                    '65a7325096d56388983d0806',
#                                    '65a6f1f00ad4bf4864caf938',
#                                    '65a931f049fb27db67a4f314',
#                                    '65a9b33349fb27db67a5021d',
#                                    '65c3d3942be6a0a6d64f6220',
#                                    '65c3d3942be6a0a6d64f6711',
#                                    '65a6ffc7ceef6a380953f038',
#                                    '65a7774f96d56388983d0a0b',
#                                    '65a773c096d56388983d09c7',
#                                    '65a72f5996d56388983d078a',
#                                    '65c3d3942be6a0a6d64f647f',
#                                    '65a9a5f449fb27db67a50125',
#                                    '65c3d3942be6a0a6d64f6374',
#                                    '65a7bd8796d56388983d0d83',
#                                    '65c3d3942be6a0a6d64f60e4',
#                                    '65c3d3942be6a0a6d64f61f1',
#                                    '65aa16ca49fb27db67a50580',
#                                    '65c3d3942be6a0a6d64f624f',
#                                    '65c3d3942be6a0a6d64f621d',
#                                    '65c3d3942be6a0a6d64f626a',
#                                    '65c3ecc62be6a0a6d64f675a',
#                                    '65c3d3942be6a0a6d64f64f3',
#                                    '65c3d3942be6a0a6d64f6733',
#                                    '65c3d3942be6a0a6d64f62b8',
#                                    '65c3d3942be6a0a6d64f655a',
#                                    '65a7b4b596d56388983d0cf7',
#                                    '65c3d3942be6a0a6d64f65bd',
#                                    '65a6e7f50692f5c8d93c5049',
#                                    '65c3d3942be6a0a6d64f6696',
#                                    '65c3d3942be6a0a6d64f5f59',
#                                    '65c3d3942be6a0a6d64f606e',
#                                    '65c3d3942be6a0a6d64f6109',
#                                    '65c3d3942be6a0a6d64f6177',
#                                    '65aa188049fb27db67a5059c',
#                                    '65a7cb9496d56388983d143d',
#                                    '65a91b3d49fb27db67a4ebcd',
#                                    '65a75ca696d56388983d099b',
#                                    '65a9de0e49fb27db67a50468',
#                                    '65c3d3942be6a0a6d64f64c3',
#                                    '65c3d3942be6a0a6d64f642e',
#                                    '65c3d3942be6a0a6d64f5f11',
#                                    '65a706a2ceef6a380953f0e6',
#                                    '65c3d3942be6a0a6d64f6576',
#                                    '65a70fd5ceef6a380953f173',
#                                    '65c3d3942be6a0a6d64f667a',
#                                    '65c3d3942be6a0a6d64f6464',
#                                    '65a94d8e49fb27db67a4fae1',
#                                    '65a988a549fb27db67a4ff70',
#                                    '65a5714aa731bd64515a5f84',
#                                    '65a7b32196d56388983d0ce4',
#                                    '65a6f1d60ad4bf4864caf928',
#                                    '65c3d3942be6a0a6d64f63fc',
#                                    '65c3d3942be6a0a6d64f6250',
#                                    '65c3d3942be6a0a6d64f6092',
#                                    '65a716b8ceef6a380953f1f2',
#                                    '65c3d3942be6a0a6d64f6663',
#                                    '65a75cac96d56388983d099e',
#                                    '65c3d3942be6a0a6d64f604c',
#                                    '65a931e749fb27db67a4f311',
#                                    '65a9a60749fb27db67a5012b',
#                                    '65a7bd9f96d56388983d0d8c',
#                                    '65a942eb49fb27db67a4fa82',
#                                    '65a6ed760ad4bf4864caf8e5',
#                                    '65a6dbeb0692f5c8d93c4fb9',
#                                    '65c3d3942be6a0a6d64f63c4',
#                                    '65aa16d249fb27db67a50583',
#                                    '65c3d3942be6a0a6d64f6184',
#                                    '65a9dacd49fb27db67a50445',
#                                    '65a956d649fb27db67a4fde8',
#                                    '65a9dfd349fb27db67a50487',
#                                    '65a6d7f0f9620005bfb27c59',
#                                    '65c3d3942be6a0a6d64f60e1',
#                                    '65a7d7a996d56388983d1475',
#                                    '65c3d3942be6a0a6d64f61d5',
#                                    '65a99e8849fb27db67a500bd',
#                                    '65c3d3942be6a0a6d64f6657',
#                                    '65a7d92b96d56388983d147c',
#                                    '65a6aa2f6ebf9d9997320526',
#                                    '65c3d3942be6a0a6d64f5ffb',
#                                    '65c3d3942be6a0a6d64f621a',
#                                    '65c3d3942be6a0a6d64f66c8',
#                                    '65a7ab7f96d56388983d0be1',
#                                    '65a72cb896d56388983d075b',
#                                    '65c3d3942be6a0a6d64f5f08',
#                                    '65c3d3942be6a0a6d64f64b1',
#                                    '65c3d3942be6a0a6d64f6741',
#                                    '65a99c5a49fb27db67a50098',
#                                    '65c3d3942be6a0a6d64f6592',
#                                    '65a778fb96d56388983d0a21',
#                                    '65a6b046bcd0c58b31680cfa',
#                                    '65a689f280d8b716415b367f',
#                                    '65c3d3942be6a0a6d64f614b',
#                                    '65a9400849fb27db67a4fa48',
#                                    '65a9392349fb27db67a4f9d6',
#                                    '65a98c0949fb27db67a4ffaa',
#                                    '65c3d3942be6a0a6d64f6430',
#                                    '65c3d3942be6a0a6d64f5ed5',
#                                    '65c3ecc62be6a0a6d64f6750',
#                                    '65c3d3942be6a0a6d64f65fb',
#                                    '65a6d7e4f9620005bfb27c53',
#                                    '65c3d3942be6a0a6d64f5f4d',
#                                    '65a5715ba731bd64515a5f8d',
#                                    '65c3d3942be6a0a6d64f64c9',
#                                    '65a9926049fb27db67a50005',
#                                    '65c3d3942be6a0a6d64f644f',
#                                    '65c3d3942be6a0a6d64f66d8',
#                                    '65c3d3942be6a0a6d64f61b1',
#                                    '65a5af8bbacca2969b0ed41d',
#                                    '65aa312349fb27db67a506a2',
#                                    '65a98c9449fb27db67a4ffb1',
#                                    '65c3d3942be6a0a6d64f62b6',
#                                    '65a7a46396d56388983d0b5e',
#                                    '65c3d3942be6a0a6d64f6068',
#                                    '65c3d3942be6a0a6d64f6582',
#                                    '65c3ecc62be6a0a6d64f674f',
#                                    '65c3d3942be6a0a6d64f612a',
#                                    '65c3ecc62be6a0a6d64f67af',
#                                    '65a73ad696d56388983d08af',
#                                    '65a9c70c49fb27db67a502f1',
#                                    '65a72f6c96d56388983d0790',
#                                    '65c3d3942be6a0a6d64f620c',
#                                    '65c3d3942be6a0a6d64f5efa',
#                                    '65a6abbdbcd0c58b31680cbf',
#                                    '65a941ef49fb27db67a4fa66',
#                                    '65a73cce96d56388983d08e0',
#                                    '65a6f7ddd4b49cbb49284e0f',
#                                    '65a9a9de49fb27db67a50157',
#                                    '65a7bba296d56388983d0d61',
#                                    '65c3d3942be6a0a6d64f6127',
#                                    '65a71760ceef6a380953f202',
#                                    '65c3d3942be6a0a6d64f5ec3',
#                                    '65c3d3942be6a0a6d64f5f09',
#                                    '65a7b31a96d56388983d0ce1',
#                                    '65a7ab6b96d56388983d0bd5',
#                                    '65c3d3942be6a0a6d64f63b5',
#                                    '65c3d3942be6a0a6d64f63b8',
#                                    '65c3d3942be6a0a6d64f6409',
#                                    '65c3d3942be6a0a6d64f6702',
#                                    '65a7c83f96d56388983d0e3f',
#                                    '65c3d3942be6a0a6d64f64b5',
#                                    '65c3d3942be6a0a6d64f62f1',
#                                    '65a7376896d56388983d087d',
#                                    '65a989ef49fb27db67a4ff8f',
#                                    '65c3d3942be6a0a6d64f6442',
#                                    '65a703caceef6a380953f0a2',
#                                    '65c3d3942be6a0a6d64f602d',
#                                    '65aa1dcb49fb27db67a505fa',
#                                    '65a986c049fb27db67a4ff57',
#                                    '65a92a5e49fb27db67a4f2d3',
#                                    '65a94bd849fb27db67a4fad1',
#                                    '65c3d3942be6a0a6d64f5f7e',
#                                    '65c3d3942be6a0a6d64f65ed',
#                                    '65a6c13f6ce432599ea774d9',
#                                    '65c3d3942be6a0a6d64f6424',
#                                    '65c3d3942be6a0a6d64f61d0',
#                                    '65c3d3942be6a0a6d64f632d',
#                                    '65c3d3942be6a0a6d64f6155',
#                                    '65c3d3942be6a0a6d64f6574',
#                                    '65c3d3942be6a0a6d64f63e5',
#                                    '65a7b30696d56388983d0cd8',
#                                    '65a73b1a96d56388983d08c7',
#                                    '65a7c45a96d56388983d0e03',
#                                    '65c3d3942be6a0a6d64f6478',
#                                    '65c3d3942be6a0a6d64f6636',
#                                    '65c3d3942be6a0a6d64f637b',
#                                    '65c3d3942be6a0a6d64f5f9a',
#                                    '65c3d3942be6a0a6d64f6119',
#                                    '65a9541549fb27db67a4fb4e',
#                                    '65c3d3942be6a0a6d64f615b',
#                                    '65a71088ceef6a380953f186',
#                                    '65a7db4196d56388983d14b0',
#                                    '65c3d3942be6a0a6d64f61ce',
#                                    '65a995d849fb27db67a50052',
#                                    '65a9dad649fb27db67a50448',
#                                    '65a70176ceef6a380953f076',
#                                    '65c3d3942be6a0a6d64f6414',
#                                    '65a6a30c20fc2d27bcbb93d3',
#                                    '65c3d3942be6a0a6d64f629d',
#                                    '65c3d3942be6a0a6d64f6471',
#                                    '65c3d3942be6a0a6d64f62e3',
#                                    '65c3d3942be6a0a6d64f65b4',
#                                    '65c3ecc62be6a0a6d64f677e',
#                                    '65aa2c1549fb27db67a50657',
#                                    '65c3d3942be6a0a6d64f6204',
#                                    '65c3ecc62be6a0a6d64f677c',
#                                    '65aa017749fb27db67a50573',
#                                    '65a9ffcf49fb27db67a5055d',
#                                    '65a7d97196d56388983d1491',
#                                    '65c3d3942be6a0a6d64f668f',
#                                    '65c3d3942be6a0a6d64f6039',
#                                    '65a7a29a96d56388983d0b42',
#                                    '65a7c0bd96d56388983d0dd4',
#                                    '65c3d3942be6a0a6d64f5fe3',
#                                    '65c3d3942be6a0a6d64f63a4',
#                                    '65a6d7dff9620005bfb27c50',
#                                    '65a7272496d56388983d06d1',
#                                    '65c3d3942be6a0a6d64f63d9',
#                                    '65a9de1d49fb27db67a5046e',
#                                    '65a7901c96d56388983d0a50',
#                                    '65a9336e49fb27db67a4f93b',
#                                    '65a9906c49fb27db67a4ffe9',
#                                    '65a6f70ad4b49cbb49284ddb',
#                                    '65a773b996d56388983d09c4',
#                                    '65a6acb3bcd0c58b31680cea',
#                                    '65a7b8be96d56388983d0d35',
#                                    '65c3d3942be6a0a6d64f66f9',
#                                    '65a7ad0d96d56388983d0c33',
#                                    '65c3d3942be6a0a6d64f6257',
#                                    '65c3d3942be6a0a6d64f673a',
#                                    '65c3d3942be6a0a6d64f5fab',
#                                    '65c3d3942be6a0a6d64f5f47',
#                                    '65c3ecc62be6a0a6d64f679c',
#                                    '65c3d3942be6a0a6d64f635a',
#                                    '65a7abc496d56388983d0bf4',
#                                    '65a922f849fb27db67a4f25a',
#                                    '65a72e7f96d56388983d0783',
#                                    '65a7772996d56388983d09fc',
#                                    '65c3d3942be6a0a6d64f61b5',
#                                    '65c3d3942be6a0a6d64f6183',
#                                    '65c3d3942be6a0a6d64f6607',
#                                    '65a9fdef49fb27db67a50532',
#                                    '65a7a7dc96d56388983d0b90',
#                                    '65a99e4c49fb27db67a500b4',
#                                    '65c3d3942be6a0a6d64f644a',
#                                    '65a7774996d56388983d0a08',
#                                    '65a9b36549fb27db67a50229',
#                                    '65c3d3942be6a0a6d64f6006',
#                                    '65a931b549fb27db67a4f2ff',
#                                    '65c3d3942be6a0a6d64f6704',
#                                    '65c3d3942be6a0a6d64f63aa',
#                                    '65c3d3942be6a0a6d64f5ec5',
#                                    '65c3d3942be6a0a6d64f665a',
#                                    '65c3d3942be6a0a6d64f6259',
#                                    '65c3d3942be6a0a6d64f66d5',
#                                    '65c3d3942be6a0a6d64f62b2',
#                                    '65c3d3942be6a0a6d64f61ef',
#                                    '65c3d3942be6a0a6d64f6008',
#                                    '65c3d3942be6a0a6d64f6621',
#                                    '65c3d3942be6a0a6d64f609a',
#                                    '65a6aa176ebf9d9997320520',
#                                    '65a942e249fb27db67a4fa7f',
#                                    '65a6fdf1d7439fece91258a8',
#                                    '65c3d3942be6a0a6d64f6384',
#                                    '65c3d3942be6a0a6d64f5f33',
#                                    '65c3d3942be6a0a6d64f626e',
#                                    '65c3d3942be6a0a6d64f6187',
#                                    '65a72f8e96d56388983d079c',
#                                    '65a6ee3c0ad4bf4864caf8fe',
#                                    '65c3d3942be6a0a6d64f5f5f',
#                                    '65a98bf649fb27db67a4ffa4',
#                                    '65a7973996d56388983d0ac3',
#                                    '65c3d3942be6a0a6d64f6270',
#                                    '65c3d3942be6a0a6d64f628e',
#                                    '65c3d3942be6a0a6d64f6082',
#                                    '65c3d3942be6a0a6d64f5fd6',
#                                    '65a6e5810692f5c8d93c5036',
#                                    '65a70baeceef6a380953f131',
#                                    '65a70e1bceef6a380953f157',
#                                    '65a7a44096d56388983d0b52',
#                                    '65c3d3942be6a0a6d64f66c6',
#                                    '65c3d3942be6a0a6d64f6180',
#                                    '65a6b752bcd0c58b31680d57',
#                                    '65c3d3942be6a0a6d64f6027',
#                                    '65a9559a49fb27db67a4fb55',
#                                    '65a9946449fb27db67a50027',
#                                    '65a72f8396d56388983d0799',
#                                    '65c3d3942be6a0a6d64f61e4',
#                                    '65c3d3942be6a0a6d64f6611',
#                                    '65c3ecc62be6a0a6d64f6766',
#                                    '65c3d3942be6a0a6d64f60e8',
#                                    '65c3d3942be6a0a6d64f5efe',
#                                    '65c3d3942be6a0a6d64f5f4b',
#                                    '65a7791396d56388983d0a2a',
#                                    '65a793db96d56388983d0a9d',
#                                    '65a7905b96d56388983d0a68',
#                                    '65c3d3942be6a0a6d64f60b5',
#                                    '65a9520549fb27db67a4fb2c',
#                                    '65a98ee449fb27db67a4ffe2',
#                                    '65aa2bfc49fb27db67a5064e',
#                                    '65a7db0096d56388983d149b',
#                                    '65c3d3942be6a0a6d64f5f58',
#                                    '65a703c3ceef6a380953f09f',
#                                    '65a6aa446ebf9d999732052f',
#                                    '65c3ecc62be6a0a6d64f67b1',
#                                    '65a6e2da0692f5c8d93c500b',
#                                    '65c3d3942be6a0a6d64f667c',
#                                    '65a91b6149fb27db67a4ebd6',
#                                    '65c3d3942be6a0a6d64f6215',
#                                    '65c3d3942be6a0a6d64f62a9',
#                                    '65c3d3942be6a0a6d64f609d',
#                                    '65a7ab6696d56388983d0bd2',
#                                    '65a7de9696d56388983d14d0',
#                                    '65c3d3942be6a0a6d64f61f3',
#                                    '65a924df49fb27db67a4f282',
#                                    '65c3d3942be6a0a6d64f604a',
#                                    '65c3d3942be6a0a6d64f6098',
#                                    '65c3d3942be6a0a6d64f600f',
#                                    '65c3d3942be6a0a6d64f5f5a',
#                                    '65a9ffd649fb27db67a50560',
#                                    '65c3d3942be6a0a6d64f646c',
#                                    '65c3d3942be6a0a6d64f6358',
#                                    '65a9b8bf49fb27db67a50271',
#                                    '65c3d3942be6a0a6d64f6475',
#                                    '65a9b6d849fb27db67a50255',
#                                    '65c3d3942be6a0a6d64f669d',
#                                    '65c3d3942be6a0a6d64f6371',
#                                    '65c3d3942be6a0a6d64f60ae',
#                                    '65a7594c96d56388983d0969',
#                                    '65a57157a731bd64515a5f8a',
#                                    '65c3d3942be6a0a6d64f65b1',
#                                    '65c3d3942be6a0a6d64f6647',
#                                    '65a931d549fb27db67a4f30b',
#                                    '65c3d3942be6a0a6d64f60c6',
#                                    '65a7074bceef6a380953f0f3',
#                                    '65c3d3942be6a0a6d64f60f3',
#                                    '65a57bab1a9a1d78f3f285af',
#                                    '65a68c4380d8b716415b3695',
#                                    '65a57b6a1a9a1d78f3f2859a',
#                                    '65c3d3942be6a0a6d64f65c8',
#                                    '65c3d3942be6a0a6d64f6084',
#                                    '65c3d3942be6a0a6d64f63df',
#                                    '65a990c349fb27db67a4fff8',
#                                    '65a70e49ceef6a380953f166',
#                                    '65a70162ceef6a380953f06a',
#                                    '65a91ef749fb27db67a4ec08',
#                                    '65a9c53549fb27db67a502db',
#                                    '65a99a7649fb27db67a5007c',
#                                    '65c3d3942be6a0a6d64f61a6',
#                                    '65c3d3942be6a0a6d64f5f6c',
#                                    '65a9193449fb27db67a4ebab',
#                                    '65a9987149fb27db67a50059',
#                                    '65a7b15d96d56388983d0cb9',
#                                    '65a93a6a49fb27db67a4f9fb',
#                                    '65c3d3942be6a0a6d64f6201',
#                                    '65a7775b96d56388983d0a0e',
#                                    '65c3d3942be6a0a6d64f6208',
#                                    '65a9302249fb27db67a4f2f2',
#                                    '65c3d3942be6a0a6d64f6649',
#                                    '65c3d3942be6a0a6d64f6337',
#                                    '65c3d3942be6a0a6d64f6520',
#                                    '65c3d3942be6a0a6d64f610f',
#                                    '65c3d3942be6a0a6d64f6062',
#                                    '65c3ecc62be6a0a6d64f6779',
#                                    '65a7255496d56388983d0415',
#                                    '65a9b8a149fb27db67a50268',
#                                    '65a9cc8a49fb27db67a5033d',
#                                    '65a7ab4096d56388983d0bcb',
#                                    '65a98cb449fb27db67a4ffb4',
#                                    '65c3d3942be6a0a6d64f61ac',
#                                    '65aa188f49fb27db67a505a2',
#                                    '65aa1a3949fb27db67a505b6',
#                                    '65c3d3942be6a0a6d64f5efd',
#                                    '65a99e2149fb27db67a500ab',
#                                    '65a95a9249fb27db67a4fe11',
#                                    '65a941b349fb27db67a4fa57',
#                                    '65c3d3942be6a0a6d64f6286',
#                                    '65c3d3942be6a0a6d64f63d0',
#                                    '65a7ad3196d56388983d0c45',
#                                    '65a9d76749fb27db67a50413',
#                                    '65c3d3942be6a0a6d64f64cf',
#                                    '65c3d3942be6a0a6d64f5f4c',
#                                    '65c3d3942be6a0a6d64f5fef',
#                                    '65c3d3942be6a0a6d64f650a',
#                                    '65a7bd7196d56388983d0d7d',
#                                    '65a9214749fb27db67a4f236',
#                                    '65c3d3942be6a0a6d64f663c',
#                                    '65a73c9596d56388983d08cb',
#                                    '65c3d3942be6a0a6d64f6299',
#                                    '65a7958096d56388983d0ab0',
#                                    '65aa30fa49fb27db67a50693',
#                                    '65c3d3942be6a0a6d64f673c',
#                                    '65a9a84549fb27db67a50147',
#                                    '65c3d3942be6a0a6d64f61f2',
#                                    '65c3d3942be6a0a6d64f6102',
#                                    '65a6fdded7439fece912589f',
#                                    '65c3d3942be6a0a6d64f6186',
#                                    '65c3d3942be6a0a6d64f62de',
#                                    '65c3d3942be6a0a6d64f6535',
#                                    '65c3d3942be6a0a6d64f66da',
#                                    '65a7d78996d56388983d146c',
#                                    '65a6b293bcd0c58b31680d13',
#                                    '65a6ff08ceef6a380953f01f',
#                                    '65c3d3942be6a0a6d64f6079',
#                                    '65c3d3942be6a0a6d64f60fc',
#                                    '65a9cac249fb27db67a50327',
#                                    '65c3d3942be6a0a6d64f6613',
#                                    '65a6fc7dd7439fece9125870',
#                                    '65c3d3942be6a0a6d64f652a',
#                                    '65c3d3942be6a0a6d64f636e',
#                                    '65c3d3942be6a0a6d64f6386',
#                                    '65c3d3942be6a0a6d64f62c6',
#                                    '65a7758a96d56388983d09e9',
#                                    '65a7ae3c96d56388983d0c96',
#                                    '65c3d3942be6a0a6d64f63ff',
#                                    '65a7792396d56388983d0a30',
#                                    '65a6a5a8d024c58447573edc',
#                                    '65c3ecc62be6a0a6d64f677a',
#                                    '65c3d3942be6a0a6d64f621f',
#                                    '65c3d3942be6a0a6d64f6105',
#                                    '65a6fc8cd7439fece9125873',
#                                    '65a9d91b49fb27db67a50429',
#                                    '65c3d3942be6a0a6d64f60b9',
#                                    '65aa1dac49fb27db67a505ee',
#                                    '65a7d5ce96d56388983d1459',
#                                    '65c3d3942be6a0a6d64f6423',
#                                    '65c3d3942be6a0a6d64f64a9',
#                                    '65a77acf96d56388983d0a46',
#                                    '65aa1f9449fb27db67a5061c',
#                                    '65c3d3942be6a0a6d64f63f1',
#                                    '65a9b6fb49fb27db67a5025e',
#                                    '65c3d3942be6a0a6d64f6688',
#                                    '65a7c85396d56388983d0e45',
#                                    '65a7bfb196d56388983d0db2',
#                                    '65a9dc8349fb27db67a5045e',
#                                    '65a71793ceef6a380953f20b',
#                                    '65c3d3942be6a0a6d64f61a9',
#                                    '65a9230049fb27db67a4f25d',
#                                    '65a6ed8e0ad4bf4864caf8ee',
#                                    '65a9177d49fb27db67a4eb95',
#                                    '65a7b65e96d56388983d0d13',
#                                    '65c3d3942be6a0a6d64f6536',
#                                    '65c3d3942be6a0a6d64f6416',
#                                    '65c3d3942be6a0a6d64f5fb0',
#                                    '65a9a9ed49fb27db67a5015a',
#                                    '65a9849949fb27db67a4ff2f',
#                                    '65a7a41e96d56388983d0b49',
#                                    '65c3d3942be6a0a6d64f6633',
#                                    '65a7cb8196d56388983d1437',
#                                    '65a70d6fceef6a380953f147',
#                                    '65a6f7d6d4b49cbb49284e0c',
#                                    '65a6b6fabcd0c58b31680d45',
#                                    '65c3d3942be6a0a6d64f62eb',
#                                    '65c3d3942be6a0a6d64f5f54',
#                                    '65a9516b49fb27db67a4fb13',
#                                    '65c3d3942be6a0a6d64f6463',
#                                    '65c3d3942be6a0a6d64f5f38',
#                                    '65c3d3942be6a0a6d64f614a',
#                                    '65a79f4996d56388983d0b04',
#                                    '65a5afadbacca2969b0ed423',
#                                    '65c3d3942be6a0a6d64f66e9',
#                                    '65a9d74249fb27db67a50407',
#                                    '65c3d3942be6a0a6d64f6058',
#                                    '65a9cdb849fb27db67a5036e',
#                                    '65c3d3942be6a0a6d64f6304',
#                                    '65a75c8c96d56388983d0992',
#                                    '65c3ecc62be6a0a6d64f675b',
#                                    '65c3d3942be6a0a6d64f65de',
#                                    '65c3d3942be6a0a6d64f65e2',
#                                    '65a94dab49fb27db67a4faea',
#                                    '65c3d3942be6a0a6d64f66f6',
#                                    '65c3d3942be6a0a6d64f625c',
#                                    '65a6dd130692f5c8d93c4fe2',
#                                    '65c3d3942be6a0a6d64f6712',
#                                    '65c3d3942be6a0a6d64f6658',
#                                    '65c3d3942be6a0a6d64f644e',
#                                    '65a6b726bcd0c58b31680d4e',
#                                    '65a958a849fb27db67a4fdfb',
#                                    '65a735d996d56388983d0870',
#                                    '65a97e0749fb27db67a4ff02',
#                                    '65c3ecc62be6a0a6d64f6789',
#                                    '65a7352296d56388983d084e',
#                                    '65c3d3942be6a0a6d64f616c',
#                                    '65a944ac49fb27db67a4fa95',
#                                    '65a689d780d8b716415b3673',
#                                    '65a7ad2096d56388983d0c3c',
#                                    '65a928a349fb27db67a4f2bd',
#                                    '65a9959849fb27db67a50043',
#                                    '65c3d3942be6a0a6d64f62ed',
#                                    '65a72b2796d56388983d072c',
#                                    '65a91f1249fb27db67a4ec11',
#                                    '65c3d3942be6a0a6d64f661e',
#                                    '65c3d3942be6a0a6d64f5f13',
#                                    '65c3d3942be6a0a6d64f6159',
#                                    '65c3d3942be6a0a6d64f617a',
#                                    '65a7ee3696d56388983d177d',
#                                    '65c3d3942be6a0a6d64f60e9',
#                                    '65c3d3942be6a0a6d64f62b0',
#                                    '65c3d3942be6a0a6d64f5f57',
#                                    '65a70d59ceef6a380953f141',
#                                    '65c3d3942be6a0a6d64f6618',
#                                    '65a7920696d56388983d0a7b',
#                                    '65c3d3942be6a0a6d64f6332',
#                                    '65c3d3942be6a0a6d64f671e',
#                                    '65a7bbae96d56388983d0d64',
#                                    '65a7a42696d56388983d0b4c',
#                                    '65c3d3942be6a0a6d64f65ae',
#                                    '65c3d3942be6a0a6d64f65f1',
#                                    '65c3d3942be6a0a6d64f5f9e',
#                                    '65c3d3942be6a0a6d64f64b6',
#                                    '65a9d1f749fb27db67a503bf',
#                                    '65a7d76796d56388983d1463',
#                                    '65c3d3942be6a0a6d64f60f0',
#                                    '65c3d3942be6a0a6d64f60ce',
#                                    '65c3ecc62be6a0a6d64f6775',
#                                    '65a7256896d56388983d0438',
#                                    '65a978cd49fb27db67a4feba',
#                                    '65a956b949fb27db67a4fddf',
#                                    '65c3d3942be6a0a6d64f655f',
#                                    '65c3d3942be6a0a6d64f5f6e',
#                                    '65a7c84896d56388983d0e42',
#                                    '65c3d3942be6a0a6d64f6104',
#                                    '65c3d3942be6a0a6d64f6446',
#                                    '65c3d3942be6a0a6d64f6445',
#                                    '65c3d3942be6a0a6d64f6106',
#                                    '65c3d3942be6a0a6d64f6135',
#                                    '65a755cb96d56388983d0931',
#                                    '65c3d3942be6a0a6d64f6206',
#                                    '65c3d3942be6a0a6d64f6253',
#                                    '65c3d3942be6a0a6d64f6306',
#                                    '65a6b504bcd0c58b31680d41',
#                                    '65c3d3942be6a0a6d64f61ee',
#                                    '65c3d3942be6a0a6d64f61c9',
#                                    '65c3d3942be6a0a6d64f60d5',
#                                    '65c3d3942be6a0a6d64f650d',
#                                    '65a73b0a96d56388983d08c1',
#                                    '65c3d3942be6a0a6d64f6047',
#                                    '65c3d3942be6a0a6d64f62e8',
#                                    '65a730e596d56388983d07bf',
#                                    '65a9fa9149fb27db67a50500',
#                                    '65c3d3942be6a0a6d64f613c',
#                                    '65a6e2b90692f5c8d93c5002',
#                                    '65c3d3942be6a0a6d64f5f73',
#                                    '65a70097ceef6a380953f04e',
#                                    '65c3d3942be6a0a6d64f62f8',
#                                    '65a9354b49fb27db67a4f998',
#                                    '65a98c1249fb27db67a4ffad',
#                                    '65c3d3942be6a0a6d64f6447',
#                                    '65c3d3942be6a0a6d64f63c8',
#                                    '65a7d97996d56388983d1494',
#                                    '65c3d3942be6a0a6d64f63cd',
#                                    '65c3d3942be6a0a6d64f65e3',
#                                    '65c3d3942be6a0a6d64f6731',
#                                    '65a735a196d56388983d085e',
#                                    '65a6ed880ad4bf4864caf8eb',
#                                    '65a755be96d56388983d092b',
#                                    '65a9b34d49fb27db67a50223',
#                                    '65aa1c0749fb27db67a505db',
#                                    '65c3d3942be6a0a6d64f648f',
#                                    '65a9fa8949fb27db67a504fd',
#                                    '65a791e096d56388983d0a72',
#                                    '65c3d3942be6a0a6d64f5f0e',
#                                    '65a6ba7a6ce432599ea77482',
#                                    '65a7174fceef6a380953f1fc',
#                                    '65a9724949fb27db67a4fe46',
#                                    '65a9c05349fb27db67a50284',
#                                    '65c3d3942be6a0a6d64f624b',
#                                    '65a7de9d96d56388983d14d3',
#                                    '65a9303f49fb27db67a4f2fb',
#                                    '65c3d3942be6a0a6d64f669c',
#                                    '65a9ff9849fb27db67a50548',
#                                    '65a7bde096d56388983d0d96',
#                                    '65c3d3942be6a0a6d64f613a',
#                                    '65a99c8049fb27db67a500a1',
#                                    '65a95a9b49fb27db67a4fe14',
#                                    '65c3d3942be6a0a6d64f667e',
#                                    '65a6aa3e6ebf9d999732052c',
#                                    '65c3d3942be6a0a6d64f6336',
#                                    '65c3d3942be6a0a6d64f63d5',
#                                    '65a9e18249fb27db67a504a0',
#                                    '65c3d3942be6a0a6d64f649f',
#                                    '65c3d3942be6a0a6d64f5ff6',
#                                    '65c3d3942be6a0a6d64f61b2',
#                                    '65a7addf96d56388983d0c74',
#                                    '65a9f8b749fb27db67a504d8',
#                                    '65c3d3942be6a0a6d64f62f3',
#                                    '65c3d3942be6a0a6d64f6510',
#                                    '65a7757f96d56388983d09e6',
#                                    '65c3d3942be6a0a6d64f5fc3',
#                                    '65c3d3942be6a0a6d64f6624',
#                                    '65aa2bf449fb27db67a5064b',
#                                    '65c3d3942be6a0a6d64f64a6',
#                                    '65c3d3942be6a0a6d64f6274',
#                                    '65a57b851a9a1d78f3f285a3',
#                                    '65a753f696d56388983d090c',
#                                    '65c3d3942be6a0a6d64f6721',
#                                    '65c3d3942be6a0a6d64f631e',
#                                    '65c3d3942be6a0a6d64f65fa',
#                                    '65a7b9ee96d56388983d0d48',
#                                    '65c3d3942be6a0a6d64f6014',
#                                    '65c3d3942be6a0a6d64f6739',
#                                    '65c3d3942be6a0a6d64f6514',
#                                    '65a57b8b1a9a1d78f3f285a6',
#                                    '65a9ffb849fb27db67a50554',
#                                    '65a9d3d249fb27db67a503db',
#                                    '65a757a496d56388983d0953',
#                                    '65a9fc2f49fb27db67a50513',
#                                    '65c3d3942be6a0a6d64f666e',
#                                    '65a9e1b249fb27db67a504b2',
#                                    '65c3d3942be6a0a6d64f5faf',
#                                    '65aa2bec49fb27db67a50648',
#                                    '65c3d3942be6a0a6d64f6324',
#                                    '65c3ecc62be6a0a6d64f674b',
#                                    '65a70af5ceef6a380953f118',
#                                    '65c3d3942be6a0a6d64f63b6',
#                                    '65c3d3942be6a0a6d64f60db',
#                                    '65c3d3942be6a0a6d64f5fa8',
#                                    '65a9945a49fb27db67a50024',
#                                    '65c3d3942be6a0a6d64f60b7',
#                                    '65c3d3942be6a0a6d64f6209',
#                                    '65c3d3942be6a0a6d64f642c',
#                                    '65c3d3942be6a0a6d64f64c7',
#                                    '65a9d74b49fb27db67a5040a',
#                                    '65c3d3942be6a0a6d64f6017',
#                                    '65c3ecc62be6a0a6d64f67ab',
#                                    '65a7ad1a96d56388983d0c39',
#                                    '65c3d3942be6a0a6d64f6048',
#                                    '65c3d3942be6a0a6d64f5f78',
#                                    '65c3d3942be6a0a6d64f6477',
#                                    '65c3d3942be6a0a6d64f65dc',
#                                    '65c3ecc62be6a0a6d64f6783',
#                                    '65a7d96796d56388983d148e',
#                                    '65a9a40649fb27db67a50100',
#                                    '65c3d3942be6a0a6d64f62e6',
#                                    '65a6bb2b6ce432599ea77498',
#                                    '65c3d3942be6a0a6d64f6198',
#                                    '65a700c4ceef6a380953f05a',
#                                    '65a7b31196d56388983d0cde',
#                                    '65c3d3942be6a0a6d64f6486',
#                                    '65c3d3942be6a0a6d64f6425',
#                                    '65a6f6e4d4b49cbb49284db2',
#                                    '65c3ecc62be6a0a6d64f6768',
#                                    '65c3d3942be6a0a6d64f5f19',
#                                    '65a70b98ceef6a380953f128',
#                                    '65c3d3942be6a0a6d64f6677',
#                                    '65a9906249fb27db67a4ffe6',
#                                    '65c3d3942be6a0a6d64f62d3',
#                                    '65c3d3942be6a0a6d64f645a',
#                                    '65a9b50a49fb27db67a50239',
#                                    '65a97c3149fb27db67a4fee3',
#                                    '65a70e24ceef6a380953f15a',
#                                    '65a7b88f96d56388983d0d26',
#                                    '65c3d3942be6a0a6d64f62ef',
#                                    '65a7956196d56388983d0aa4',
#                                    '65a941e649fb27db67a4fa63',
#                                    '65a9a25a49fb27db67a500f6',
#                                    '65a7277896d56388983d06e1',
#                                    '65c3d3942be6a0a6d64f639a',
#                                    '65a9198149fb27db67a4ebbd',
#                                    '65a9850949fb27db67a4ff44',
#                                    '65a99a9449fb27db67a50082',
#                                    '65c3d3942be6a0a6d64f62c5',
#                                    '65c3d3942be6a0a6d64f66c2',
#                                    '65c3d3942be6a0a6d64f649c',
#                                    '65a54b3d2b32912eefb9ea69',
#                                    '65c3d3942be6a0a6d64f5f7c',
#                                    '65a703feceef6a380953f0ae',
#                                    '65a9c06849fb27db67a5028a',
#                                    '65c3d3942be6a0a6d64f66d0',
#                                    '65a5780c12d40c7ee3f95e61',
#                                    '65c3d3942be6a0a6d64f608a',
#                                    '65c3d3942be6a0a6d64f65c5',
#                                    '65a71090ceef6a380953f189',
#                                    '65c3d3942be6a0a6d64f60e0',
#                                    '65a7ab5f96d56388983d0bcf',
#                                    '65c3d3942be6a0a6d64f6053',
#                                    '65c3ecc62be6a0a6d64f6765',
#                                    '65a920a849fb27db67a4ec1b',
#                                    '65c3d3942be6a0a6d64f64fb',
#                                    '65c3d3942be6a0a6d64f6226',
#                                    '65c3d3942be6a0a6d64f5fdf',
#                                    '65a93e3249fb27db67a4fa29',
#                                    '65a7cb5096d56388983d142b',
#                                    '65a7b4aa96d56388983d0cf1',
#                                    '65c3d3942be6a0a6d64f5f55',
#                                    '65a9dc8f49fb27db67a50461',
#                                    '65c3d3942be6a0a6d64f63ca',
#                                    '65c3d3942be6a0a6d64f63d3',
#                                    '65a7b4b096d56388983d0cf4',
#                                    '65a99c3349fb27db67a5008f',
#                                    '65a7cb8996d56388983d143a',
#                                    '65c3d3942be6a0a6d64f5f50',
#                                    '65c3d3942be6a0a6d64f5f61',
#                                    '65c3d3942be6a0a6d64f5fbb',
#                                    '65c3d3942be6a0a6d64f60bc',
#                                    '65c3d3942be6a0a6d64f6260',
#                                    '65a9c52349fb27db67a502d5',
#                                    '65c3d3942be6a0a6d64f6189',
#                                    '65a7ac1396d56388983d0c0a',
#                                    '65c3d3942be6a0a6d64f63c5',
#                                    '65c3d3942be6a0a6d64f656c',
#                                    '65c3d3942be6a0a6d64f6342',
#                                    '65a773de96d56388983d09d3',
#                                    '65c3d3942be6a0a6d64f614d',
#                                    '65a7c0e896d56388983d0dda',
#                                    '65c3d3942be6a0a6d64f6256',
#                                    '65a9a1f649fb27db67a500e1',
#                                    '65c3d3942be6a0a6d64f6277',
#                                    '65c3d3942be6a0a6d64f60c1',
#                                    '65a9cab049fb27db67a50324',
#                                    '65a6852b80d8b716415b3653',
#                                    '65a9868549fb27db67a4ff48',
#                                    '65c3ecc62be6a0a6d64f6787',
#                                    '65a9a9ce49fb27db67a50151',
#                                    '65a72b3796d56388983d0735',
#                                    '65c3d3942be6a0a6d64f61c4',
#                                    '65a9771049fb27db67a4fe9e',
#                                    '65c3d3942be6a0a6d64f5f49',
#                                    '65c3d3942be6a0a6d64f63c1',
#                                    '65c3ecc62be6a0a6d64f6782',
#                                    '65a9fa7949fb27db67a504f7',
#                                    '65a7c0d696d56388983d0dd7',
#                                    '65a7bdf496d56388983d0d9c',
#                                    '65c3d3942be6a0a6d64f66e5',
#                                    '65a9374049fb27db67a4f9ba',
#                                    '65c3d3942be6a0a6d64f623b',
#                                    '65c3d3942be6a0a6d64f6146',
#                                    '65a9372949fb27db67a4f9b7',
#                                    '65c3d3942be6a0a6d64f607c',
#                                    '65c3d3942be6a0a6d64f6052',
#                                    '65c3d3942be6a0a6d64f618d',
#                                    '65c3d3942be6a0a6d64f612f',
#                                    '65c3d3942be6a0a6d64f6394',
#                                    '65c3d3942be6a0a6d64f6283',
#                                    '65c3d3942be6a0a6d64f665f',
#                                    '65c3ecc62be6a0a6d64f679e',
#                                    '65c3d3942be6a0a6d64f5ee8',
#                                    '65a71679ceef6a380953f1da',
#                                    '65a6ba4c6ce432599ea77440',
#                                    '65c3d3942be6a0a6d64f5fa2',
#                                    '65a726da96d56388983d06bf',
#                                    '65c3d3942be6a0a6d64f6481',
#                                    '65a9467949fb27db67a4faae',
#                                    '65a9208e49fb27db67a4ec15',
#                                    '65c3d3942be6a0a6d64f6460',
#                                    '65a7376f96d56388983d0880',
#                                    '65c3d3942be6a0a6d64f6065',
#                                    '65a955a649fb27db67a4fb58',
#                                    '65a6bb156ce432599ea7748f',
#                                    '65a92a8c49fb27db67a4f2df',
#                                    '65c3d3942be6a0a6d64f6137',
#                                    '65c3d3942be6a0a6d64f65c1',
#                                    '65a9b31949fb27db67a50219',
#                                    '65a7d95b96d56388983d148b',
#                                    '65c3d3942be6a0a6d64f64ed',
#                                    '65c3d3942be6a0a6d64f607e',
#                                    '65c3d3942be6a0a6d64f5efc',
# ...
#                                               'Saffron',
#                                               'Mandarin Orange',
#                                               'Almond',
#                                               'Neroli',
#                                               'Bergamot',
#                                               'Bitter Orange',
#                                               'Bergamot',
#                                               'Bergamot',
#                                               'Grapefruit',
#                                               'Pepper',
#                                               'Bergamot',
#                                               'Ginger',
#                                               'Peach',
#                                               'Cardamom',
#                                               'Galbanum',
#                                               'Orange Blossom',
#                                               'Bergamot',
#                                               'Rum',
#                                               'Clove',
#                                               'Pineapple',
#                                               'Raspberry',
#                                               'Mandarin Orange',
#                                               'Jasmine Sambac',
#                                               'Citrus Leaf',
#                                               'Peony',
#                                               'Cardamom',
#                                               'Ginger']}]},
#                        {'bsonType': 'Undefined',
#                         'count': 478,
#                         'hasDuplicates': True,
#                         'name': 'Undefined',
#                         'path': ['top notes'],
#                         'probability': 0.478,
#                         'unique': 0}]},
#             {'count': 496,
#              'hasDuplicates': True,
#              'name': 'url',
#              'path': ['url'],
#              'probability': 0.496,
#              'type': ['String', 'Undefined'],
#              'types': [{'bsonType': 'String',
#                         'count': 496,
#                         'hasDuplicates': False,
#                         'name': 'String',
#                         'path': ['url'],
#                         'probability': 0.496,
#                         'unique': 100,
#                         'values': ['https://www.fragrantica.com/perfume/Dior/Miss-Dior-Rose-Essence-73762.html',
#                                    'https://www.fragrantica.com/perfume/Escada/Escada-Sentiment-1179.html',
#                                    'https://www.fragrantica.com/perfume/Commodity/Velvet-70016.html',
#                                    'https://www.fragrantica.com/perfume/Paco-Rabanne/Olympea-31666.html',
#                                    'https://www.fragrantica.com/perfume/Cupid-Perfumes/Cupid-No-5-45561.html',
#                                    'https://www.fragrantica.com/perfume/Burberry/Mr-Burberry-Element-60796.html',
#                                    'https://www.fragrantica.com/perfume/Acqua-di-Parma/Chinotto-di-Liguria-48940.html',
#                                    'https://www.fragrantica.com/perfume/Maurer-Wirtz/GranValor-Tabac-1749.html',
#                                    'https://www.fragrantica.com/perfume/Fresh/Fresh-Life-18955.html',
#                                    'https://www.fragrantica.com/perfume/Sephora/Eau-Sucree-Salee-Vanille-Fleur-de-Sel-62126.html',
#                                    'https://www.fragrantica.com/perfume/Tiziana-Terenzi/Cubia-61875.html',
#                                    'https://www.fragrantica.com/perfume/Atelier-Cologne/Bergamote-Soleil-35155.html',
#                                    'https://www.fragrantica.com/perfume/Vilhelm-Parfumerie/Do-Not-Disturb-42672.html',
#                                    'https://www.fragrantica.com/perfume/Bvlgari/Bvlgari-Man-In-Black-Essence-46312.html',
#                                    'https://www.fragrantica.com/perfume/Yves-Saint-Laurent/37-rue-de-Bellechasse-47736.html',
#                                    'https://www.fragrantica.com/perfume/Cartier/Must-de-Cartier-Parfum-2015-34584.html',
#                                    'https://www.fragrantica.com/perfume/Lattafa-Perfumes/Haya-85031.html',
#                                    'https://www.fragrantica.com/perfume/Nicolai-Parfumeur-Createur/Cap-Neroli-48543.html',
#                                    'https://www.fragrantica.com/perfume/Victoria-s-Secret/Victoria-s-Secret-Forbidden-23244.html',
#                                    'https://www.fragrantica.com/perfume/Xerjoff/Pikovaya-Dama-31624.html',
#                                    'https://www.fragrantica.com/perfume/Maison-Tahite-Officine-Creative-Profumi/Cafe-Gourmand-76417.html',
#                                    'https://www.fragrantica.com/perfume/Viktor-Rolf/Flowerbomb-Extreme-2007-1792.html',
#                                    'https://www.fragrantica.com/perfume/Zara/TOB-03-Tabac-Treasure-87739.html',
#                                    'https://www.fragrantica.com/perfume/Navitus-Parfums/Ambrosia-Imperiale-81976.html',
#                                    'https://www.fragrantica.com/perfume/Antiga-Barbearia-de-Bairro/Ribeira-Porto-23873.html',
#                                    'https://www.fragrantica.com/perfume/Mugler/Alien-We-Are-All-Alien-Collector-Edition-51521.html',
#                                    'https://www.fragrantica.com/perfume/Lattafa-Perfumes/Ra-ed-Luxe-65392.html',
#                                    'https://www.fragrantica.com/perfume/Jesus-Del-Pozo/On-El-6873.html',
#                                    'https://www.fragrantica.com/perfume/Sospiro-Perfumes/Muse-49505.html',
#                                    'https://www.fragrantica.com/perfume/Giorgio-Armani/Pivoine-Suzhou-29301.html',
#                                    'https://www.fragrantica.com/perfume/O-Boticario/Floratta-Fleur-Supreme-63783.html',
#                                    'https://www.fragrantica.com/perfume/Lalique/Encre-Noire-A-L-Extreme-32356.html',
#                                    'https://www.fragrantica.com/perfume/Melvita/Floral-Water-Cornflower-10374.html',
#                                    'https://www.fragrantica.com/perfume/Guerlain/Cruel-Gardenia-2283.html',
#                                    'https://www.fragrantica.com/perfume/Paris-Elysees/Vodka-Brasil-Yellow-35283.html',
#                                    'https://www.fragrantica.com/perfume/Le-Labo/Rose-31-3678.html',
#                                    'https://www.fragrantica.com/perfume/Dzintars/Lucky-Number-7-20286.html',
#                                    'https://www.fragrantica.com/perfume/Rosendo-Mateu-Olfactive-Expressions/1970-80352.html',
#                                    'https://www.fragrantica.com/perfume/Bottega-Veneta/Parco-Palladiano-XV-Salvia-Blu-50845.html',
#                                    'https://www.fragrantica.com/perfume/Natura/Kaiak-12384.html',
#                                    'https://www.fragrantica.com/perfume/Avon/Intrigue-11497.html',
#                                    'https://www.fragrantica.com/perfume/Coach/Coach-Wild-Rose-72051.html',
#                                    'https://www.fragrantica.com/perfume/Bohoboco/Eternal-Lily-Amber-77856.html',
#                                    'https://www.fragrantica.com/perfume/Vertus/Eau-de-Cyan-40554.html',
#                                    'https://www.fragrantica.com/perfume/Granado/Jardim-Real-77488.html',
#                                    'https://www.fragrantica.com/perfume/Amouage/Figment-Woman-45291.html',
#                                    'https://www.fragrantica.com/perfume/Montale/Oud-Pashmina-64641.html',
#                                    'https://www.fragrantica.com/perfume/Perfumer-s-Workshop/Samba-Kiss-5489.html',
#                                    'https://www.fragrantica.com/perfume/Hermes/Eau-de-Narcisse-Bleu-18184.html',
#                                    'https://www.fragrantica.com/perfume/Maison-Crivelli/Papyrus-Moleculaire-59189.html',
#                                    'https://www.fragrantica.com/perfume/Atelier-Materi/Santal-Blond-57097.html',
#                                    'https://www.fragrantica.com/perfume/DSQUARED2/Red-Wood-58067.html',
#                                    'https://www.fragrantica.com/perfume/Castle-Forbes/Forbes-Limes-30534.html',
#                                    'https://www.fragrantica.com/perfume/Imaginary-Authors/Slow-Explosions-40420.html',
#                                    'https://www.fragrantica.com/perfume/Avon/Derek-Jeter-Driven-2316.html',
#                                    'https://www.fragrantica.com/perfume/Molton-Brown/Tobacco-Absolute-36043.html',
#                                    'https://www.fragrantica.com/perfume/City/City-Sexy-Sweet-Cats-23382.html',
#                                    'https://www.fragrantica.com/perfume/Guerlain/Aqua-Allegoria-Passiflora-48678.html',
#                                    'https://www.fragrantica.com/perfume/Serge-Lutens/Clair-de-Musc-2763.html',
#                                    'https://www.fragrantica.com/perfume/Mes-Bisous/Tobacco-Flirting-With-Vanilla-73512.html',
#                                    'https://www.fragrantica.com/perfume/Guerlain/Aqua-Allegoria-Nettare-di-Sole-66360.html',
#                                    'https://www.fragrantica.com/perfume/Bella-Aura/Exalte-by-Funmi-Monet-72681.html',
#                                    'https://www.fragrantica.com/perfume/Lorenzo-Pazzaglia/Passion-Rose-74240.html',
#                                    'https://www.fragrantica.com/perfume/Yves-Rocher/Matin-Blanc-56462.html',
#                                    'https://www.fragrantica.com/perfume/Ralph-Lauren/Midnight-Romance-23574.html',
#                                    'https://www.fragrantica.com/perfume/Jo-Malone-London/Rose-Blush-Cologne-2024-89143.html',
#                                    'https://www.fragrantica.com/perfume/Tigha/The-Dark-Side-61207.html',
#                                    'https://www.fragrantica.com/perfume/Montana/Montana-Mood-Sexy-2376.html',
#                                    'https://www.fragrantica.com/perfume/American-Idol/Idol-Moments-for-Her-12745.html',
#                                    'https://www.fragrantica.com/perfume/Jovoy-Paris/Poudre-3123.html',
#                                    'https://www.fragrantica.com/perfume/Aerin-Lauder/Rose-Cocoa-56979.html',
#                                    'https://www.fragrantica.com/perfume/Estee-Lauder/Dream-Dusk-69705.html',
#                                    'https://www.fragrantica.com/perfume/Oriflame/Miss-Giordani-28132.html',
#                                    'https://www.fragrantica.com/perfume/Mugler/Mirror-Mirror-Collection-Miroir-Des-Vanites-2370.html',
#                                    'https://www.fragrantica.com/perfume/Victoria-s-Secret/XO-Victoria-35869.html',
#                                    'https://www.fragrantica.com/perfume/Puma/Flowing-1083.html',
#                                    'https://www.fragrantica.com/perfume/La-Perla/Just-Precious-18845.html',
#                                    'https://www.fragrantica.com/perfume/Demeter-Fragrance/Frankincense-30758.html',
#                                    'https://www.fragrantica.com/perfume/Dior/Dior-Homme-Cologne-1770.html',
#                                    'https://www.fragrantica.com/perfume/Chanel/Gabrielle-43718.html',
#                                    'https://www.fragrantica.com/perfume/Yves-Rocher/Quelques-Notes-d-Amour-26251.html',
#                                    'https://www.fragrantica.com/perfume/Esprit/Life-by-Esprit-Men-1345.html',
#                                    'https://www.fragrantica.com/perfume/Hotel-Hassler-Roma/Amorvero-13503.html',
#                                    'https://www.fragrantica.com/perfume/Faberlic/Fortunata-22931.html',
#                                    'https://www.fragrantica.com/perfume/Michael-Malul-London/Terra-Nova-78421.html',
#                                    'https://www.fragrantica.com/perfume/Masque-Milano/Petra-Le-Donne-di-Masque-59747.html',
#                                    'https://www.fragrantica.com/perfume/Divine/L-Infante-44.html',
#                                    'https://www.fragrantica.com/perfume/Victoria-s-Secret/Wicked-Eau-de-Parfum-46141.html',
#                                    'https://www.fragrantica.com/perfume/Body-Fantasies/Sweet-Sunrise-58607.html',
#                                    'https://www.fragrantica.com/perfume/Entre-Filles/Saison-2-3139.html',
#                                    'https://www.fragrantica.com/perfume/Jul-et-Mad-Paris/Fugit-Amor-43979.html',
#                                    'https://www.fragrantica.com/perfume/Naomi-Campbell/Naomi-Campbell-Light-Edition-29197.html',
#                                    'https://www.fragrantica.com/perfume/Maison-Rebatchi/Bois-d-Enfant-51513.html',
#                                    'https://www.fragrantica.com/perfume/Maison-Francis-Kurkdjian/Aqua-Celestia-42268.html',
#                                    'https://www.fragrantica.com/perfume/Esteban/Modern-Chypre-3391.html',
#                                    'https://www.fragrantica.com/perfume/Molton-Brown/Milk-Musk-Eau-de-Parfum-59436.html',
#                                    'https://www.fragrantica.com/perfume/Prin/Saringkarn-vngkhar-62883.html',
#                                    'https://www.fragrantica.com/perfume/Paglieri/Amalphia-37337.html',
#                                    'https://www.fragrantica.com/perfume/Kyse-Perfumes/Macarons-67005.html',
#                                    'https://www.fragrantica.com/perfume/Amouage/Overture-Man-55859.html']},
#                        {'bsonType': 'Undefined',
#                         'count': 504,
#                         'hasDuplicates': True,
#                         'name': 'Undefined',
#                         'path': ['url'],
#                         'probability': 0.504,
#                         'unique': 0}]},
#             {'count': 26,
#              'hasDuplicates': True,
#              'name': 'year',
#              'path': ['year'],
#              'probability': 0.026,
#              'type': ['Int32', 'Undefined'],
#              'types': [{'bsonType': 'Int32',
#                         'count': 26,
#                         'hasDuplicates': True,
#                         'name': 'Int32',
#                         'path': ['year'],
#                         'probability': 0.026,
#                         'unique': 6,
#                         'values': [2020,
#                                    2020,
#                                    2021,
#                                    2023,
#                                    2022,
#                                    2021,
#                                    2022,
#                                    2023,
#                                    2021,
#                                    2022,
#                                    2023,
#                                    2022,
#                                    2022,
#                                    2018,
#                                    2020,
#                                    2021,
#                                    2020,
#                                    2022,
#                                    2020,
#                                    2020,
#                                    2023,
#                                    2019,
#                                    2019,
#                                    2023,
#                                    2022,
#                                    2021]},
#                        {'bsonType': 'Undefined',
#                         'count': 974,
#                         'hasDuplicates': True,
#                         'name': 'Undefined',
#                         'path': ['year'],
#                         'probability': 0.974,
#                         'unique': 0}]}]}

# %%
print(quality_analysis.keys())
# Out:
# dict_keys(['_id', 'count', 'fields', 'Date'])

# %%
available_fields = [field["name"] for field in quality_analysis["fields"]]

# %% [markdown]
# A list of all fields present in the dataset

# %%
print(available_fields)
# Out:
# ['_id', 'base notes', 'company', 'description', 'gender', 'gender_vote', 'image', 'link', 'longevity', 'main accords', 'middle notes', 'name', 'notes', 'number_votes', 'price', 'price value', 'rating', 'sillage', 'top notes', 'url', 'year']

# %% [markdown]
# ## Completeness

# %%
def calculate_field_completeness(field, analysis_document):
    
    find_field = lambda f: next((idx for idx, i in enumerate(analysis_document["fields"]) if i["name"] == f), None)
    fields = analysis_document["fields"]
    field = fields[find_field(field)]
    
    types = field["types"]
    
    undefined_probability = next((i["probability"] for i in types if i["name"] == "Undefined"), 0)
    
    return undefined_probability

# %%
for field in [field["name"] for field in quality_analysis["fields"]]:
    print(f"The field \"{field}\"'s completeness is: {round(1 - calculate_field_completeness(field, quality_analysis), 2)}")
# Out:
# The field "_id"'s completeness is: 1
# The field "base notes"'s completeness is: 0.52
# The field "company"'s completeness is: 1
# The field "description"'s completeness is: 0.97
# The field "gender"'s completeness is: 0.5
# The field "gender_vote"'s completeness is: 0.5
# The field "image"'s completeness is: 0.97
# The field "link"'s completeness is: 0.03
# The field "longevity"'s completeness is: 0.5
# The field "main accords"'s completeness is: 0.5
# The field "middle notes"'s completeness is: 0.52
# The field "name"'s completeness is: 1
# The field "notes"'s completeness is: 0.47
# The field "number_votes"'s completeness is: 0.5
# The field "price"'s completeness is: 0.03
# The field "price value"'s completeness is: 0.5
# The field "rating"'s completeness is: 0.5
# The field "sillage"'s completeness is: 0.5
# The field "top notes"'s completeness is: 0.52
# The field "url"'s completeness is: 0.5
# The field "year"'s completeness is: 0.03

# %% [markdown]
# ## Redundancy

# %% [markdown]
# ## Consistency

# %%
types_dict = {field['name']: field['type'] for field in quality_analysis["fields"]}

# %% [markdown]
# The fields can have multiple formats, below is different bson data types that the fields have.

# %%
types_dict
# Out:
# {'_id': 'ObjectId',
#  'base notes': ['Array', 'Undefined'],
#  'company': 'String',
#  'description': ['String', 'Undefined'],
#  'gender': ['String', 'Undefined'],
#  'gender_vote': ['Document', 'Undefined'],
#  'image': ['String', 'Undefined'],
#  'link': ['Array', 'Undefined'],
#  'longevity': ['Document', 'Undefined'],
#  'main accords': ['Document', 'Undefined'],
#  'middle notes': ['Array', 'Undefined'],
#  'name': 'String',
#  'notes': ['String', 'Undefined'],
#  'number_votes': ['Int32', 'String', 'Undefined'],
#  'price': ['String', 'Undefined'],
#  'price value': ['Document', 'Undefined'],
#  'rating': ['Double', 'String', 'Undefined'],
#  'sillage': ['Document', 'Undefined'],
#  'top notes': ['Array', 'Undefined'],
#  'url': ['String', 'Undefined'],
#  'year': ['Int32', 'Undefined']}

# %% [markdown]
# ### Notes Consistency

# %% [markdown]
# Inorder to assess notes consistency, all notes are extracted using the following pipeline.

# %%
extract_unique_notes = [
    {
        '$project': {
            'all_notes': {
                '$concatArrays': [
                    {
                        '$ifNull': [
                            '$top notes', []
                        ]
                    }, {
                        '$ifNull': [
                            '$base notes', []
                        ]
                    }, {
                        '$ifNull': [
                            '$middle notes', []
                        ]
                    }, {
                        '$ifNull': [
                            '$notes', []
                        ]
                    }
                ]
            }
        }
    }, {
        '$set': {
            'length': {
                '$size': '$all_notes'
            }
        }
    }, {
        '$sort': {
            'length': -1
        }
    }, {
        '$unwind': {
            'path': '$all_notes'
        }
    }, {
        '$group': {
            '_id': '$all_notes', 
            'count': {
                '$count': {}
            }
        }
    }, {
        '$sort': {
            'count': -1
        }
    }, {
        '$project': {
            'note': '$_id', 
            '_id': 0
        }
    }
]

# %%
notes_result = fragrances_collection.aggregate(extract_unique_notes)

# %%
notes_list = list(notes_result)

# %%
note_literal_list = [note["note"] for note in notes_list]

# %%
print(f"The number of unprocessed unique notes present in Fragrances collection are {len(note_literal_list)}")
# Out:
# The number of unprocessed unique notes present in Fragrances collection are 4580

# %% [markdown]
# Check the trimmed and lowercased notes count

# %%
processed_notes_pipeline_count = [
    {
        '$project': {
            'all_notes': {
                '$concatArrays': [
                    {
                        '$ifNull': [
                            '$top notes', []
                        ]
                    }, {
                        '$ifNull': [
                            '$base notes', []
                        ]
                    }, {
                        '$ifNull': [
                            '$middle notes', []
                        ]
                    }, {
                        '$ifNull': [
                            '$notes', []
                        ]
                    }
                ]
            }
        }
    }, {
        '$set': {
            'length': {
                '$size': '$all_notes'
            }
        }
    }, {
        '$sort': {
            'length': -1
        }
    }, {
        '$unwind': {
            'path': '$all_notes'
        }
    }, {
        '$group': {
            '_id': {
                '$trim': {
                    'input': {
                        '$toLower': '$all_notes'
                    }
                }
            }, 
            'count': {
                '$sum': 1
            }, 
            'variants': {
                '$push': '$all_notes'
            }
        }
    }, {
        '$count': 'count'
    }
]

# %%
print(f"The number of unique lowercased and trimmed notes are: {fragrances_collection.aggregate(processed_notes_pipeline_count).next()['count']}")
# Out:
# The number of unique lowercased and trimmed notes are: 3671

# %% [markdown]
# An analysis is required after reparsing the notes field

# %%
notes_result = fragrances_collection.aggregate(extract_unique_notes)

# %%
notes_list = list(notes_result)

# %%
note_literal_list = [note["note"] for note in notes_list]

# %%
print(f"The number of unprocessed unique notes present in Fragrances collection are {len(note_literal_list)}")
# Out:
# The number of unprocessed unique notes present in Fragrances collection are 4115

# %% [markdown]
# Applying the previous processing of lowercasing and trimming gives us the following result:

# %%
print(f"The number of unique lowercased and trimmed notes are: {fragrances_collection.aggregate(processed_notes_pipeline_count).next()['count']}")
# Out:
# The number of unique lowercased and trimmed notes are: 3353

# %% [markdown]
# #### Calculate Similarity

# %%
import itertools
import pandas as pd
from difflib import SequenceMatcher

# %%
# similarity_matrix = pd.DataFrame(index=note_literal_list_lowercase, columns=note_literal_list_lowercase)

# %%
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
def calculate_similarity(note1, note2):
  # Replace this with your actual similarity function
  # This is just a placeholder example
    similarity = SequenceMatcher(None, note1, note2).ratio()
    return similarity

# %%
def all_pairs_similarity(notes, similarity_func, similarity_matrix):
    
    combos = itertools.combinations(notes, 2)
    
    for note1, note2 in combos:
        similarity_matrix.loc[note1, note2] = similarity_func(note1, note2)

    return similarity_matrix

# %%
# all_pairs_similarity(note_literal_list_lowercase, calculate_similarity, similarity_matrix)
# Out:
#                           musk  bergamot   vanilla     amber sandalwood  \
# musk                       1.0  0.166667       0.0  0.222222   0.142857
# bergamot              0.166667       1.0  0.133333  0.461538   0.222222
# vanilla                    0.0  0.133333       1.0  0.166667   0.352941
# amber                 0.222222  0.461538  0.166667       1.0   0.133333
# sandalwood            0.142857  0.222222  0.352941  0.133333        1.0
# ...                        ...       ...       ...       ...        ...
# namasoma                   NaN       NaN       NaN       NaN        NaN
# cipriol                    NaN       NaN       NaN       NaN        NaN
# haitian vetyver root       NaN       NaN       NaN       NaN        NaN
# graphite                   NaN       NaN       NaN       NaN        NaN
# nanah mint                 NaN       NaN       NaN       NaN        NaN
#
#                      patchouli   jasmine      rose     cedar      musk  ...  \
# musk                  0.153846  0.181818      0.25       0.0       1.0  ...
# bergamot              0.235294  0.133333  0.166667  0.307692  0.166667  ...
# vanilla                   0.25  0.285714       0.0  0.166667       0.0  ...
# amber                 0.142857       0.5  0.222222       0.4  0.222222  ...
# sandalwood            0.210526  0.235294  0.142857  0.266667  0.142857  ...
# ...                        ...       ...       ...       ...       ...  ...
# namasoma                   NaN       NaN       NaN       NaN       NaN  ...
# cipriol                    NaN       NaN       NaN       NaN       NaN  ...
# haitian vetyver root       NaN       NaN       NaN       NaN       NaN  ...
# graphite                   NaN       NaN       NaN       NaN       NaN  ...
# nanah mint                 NaN       NaN       NaN       NaN       NaN  ...
#
#                      snow flake accord white currant pink pepper essence  \
# musk                          0.190476      0.117647            0.086957
# bergamot                          0.16      0.380952            0.148148
# vanilla                           0.25           0.2            0.076923
# amber                         0.272727      0.111111            0.166667
# sandalwood                    0.222222      0.173913            0.137931
# ...                                ...           ...                 ...
# namasoma                           NaN           NaN                 NaN
# cipriol                            NaN           NaN                 NaN
# haitian vetyver root               NaN           NaN                 NaN
# graphite                           NaN           NaN                 NaN
# nanah mint                    0.222222       0.26087            0.137931
#
#                      smoked cedar with a little bit of pollution (benzoin  \
# musk                                                           0.071429
# bergamot                                                            0.1
# vanilla                                                        0.135593
# amber                                                          0.105263
# sandalwood                                                     0.193548
# ...                                                                 ...
# namasoma                                                            NaN
# cipriol                                                             NaN
# haitian vetyver root                                                NaN
# graphite                                                            NaN
# nanah mint                                                      0.16129
#
#                      birch essence  namasoma   cipriol haitian vetyver root  \
# musk                      0.117647  0.333333       0.0                  0.0
# bergamot                  0.190476     0.375  0.266667             0.285714
# vanilla                        0.1  0.266667  0.285714             0.148148
# amber                     0.222222  0.307692  0.166667                 0.24
# sandalwood                0.173913  0.222222  0.117647             0.266667
# ...                            ...       ...       ...                  ...
# namasoma                       NaN       NaN  0.133333             0.142857
# cipriol                        NaN       NaN       NaN             0.222222
# haitian vetyver root           NaN       NaN       NaN                  NaN
# graphite                       NaN       NaN       NaN                  NaN
# nanah mint                 0.26087  0.444444  0.117647             0.266667
#
#                       graphite nanah mint
# musk                       0.0   0.142857
# bergamot                 0.125   0.333333
# vanilla               0.266667   0.352941
# amber                 0.307692   0.266667
# sandalwood            0.111111        0.3
# ...                        ...        ...
# namasoma                 0.125   0.333333
# cipriol               0.133333   0.117647
# haitian vetyver root  0.285714   0.266667
# graphite                   NaN   0.444444
# nanah mint            0.444444        1.0
#
# [4580 rows x 4580 columns]

# %%
# similarity_matrix.to_csv("Similarity_Matrix.csv")
